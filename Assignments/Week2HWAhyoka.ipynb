# %% [markdown]
# <a href="https://colab.research.google.com/github/aslater-mc/aslater---DATA-110-22016/blob/DATA-110-Assignments/Week2HWAhyoka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Anscombe's Quartet:
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x,y1)

# %%
m, b = np.polyfit(x, y1, 1)

# %%
regression_line = m * np.array(x) + b

# %%
plt.scatter(x, y1)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y1')
# Out:
# Text(0, 0.5, 'y1')

# %% [markdown]
# ## **TASK QUESTIONS:**

# %%
plt.scatter(x, y2)
plt.plot(x, regression_line,color='pink')
plt.xlabel('X')
plt.grid()
plt.ylabel('Y2')
# Out:
# Text(0, 0.5, 'Y2')

# %%
plt.scatter(x, y3)
plt.plot(x, regression_line,color='green')
plt.xlabel('X')
plt.grid()
plt.ylabel('Y3')
# Out:
# Text(0, 0.5, 'Y3')

# %%
plt.scatter(x, y4)
plt.plot(x, regression_line,color='lightgreen')
plt.grid()
plt.xlabel('X')
plt.ylabel('Y4')
# Out:
# Text(0, 0.5, 'Y4')

# %%
plt.scatter(x4, y4)
plt.plot(x, regression_line,color='lightblue')
plt.grid()
plt.xlabel('X4')
plt.ylabel('Y4')
# Out:
# Text(0, 0.5, 'Y4')

# %% [markdown]
# ### **Reflection:**

# %% [markdown]
# *   **Why is it important to visualize data in addition to calculating summary statistics?**
#
# > When it comes to data, unless it is an incredibly small set of data it would be hard to quickly and efficently read that data. Data visulaization allows data to be quickly and effciently shown to both data analysts and the average consumer alike, it concentrates and simplifies the data getting right down to the point and summarizing its satistics.
#
#
# *  **How did the outlier in the x4, y4 dataset affect the regression line compared to the other datasets?**
#
# > It caused the graph to be way larger than the line could even compensate for, leading the outlier to be shown far away off of the line.
#
# *   **How do the datasets visually differ despite having similar summary statistics?**
#
# > Datasets can be summarized in all sorts of different ways, for example, two of the same data sets can be visualized differently.
